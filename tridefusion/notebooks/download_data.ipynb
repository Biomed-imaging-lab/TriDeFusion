# %% [markdown]
# # Загрузка датасета и предобученной модели

# %% [markdown]
# ## Загрузка предобученной модели

# %%
# %%bash
# chmod +x download_pretrained.sh
# ./download_pretrained.sh

# %% [markdown]
# ## Загрузка датасета

# %%
# %%bash
# chmod +x download_dataset.sh
# ./download_dataset.sh
