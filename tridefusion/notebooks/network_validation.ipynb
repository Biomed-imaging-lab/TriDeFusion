# %% [markdown]
# # Journal of validation for the denoising network results
#
# This journal is dedicated to validating the performance of the trained network on synthetic images and visualizing its effectiveness on real data.
# The following validation scenario is proposed:
# 1. Validation on synthetic spheres and sticks
#   - Metrics: PSNR, RMSE, time execution.
#   - Visual analysis: line profiles, comparison of remote noise and source noise (different point-to-point difference maps).
#   - Visual analysis.
#   - PSNR+RMSE score for different noise levels (1, 2, 4, 8, 16).
#
# 2. Validation on real data (tubes and neuron)
#   - Time execution + line profiles.
#   - Noise statistics (Mean, variance, standard deviation).
#   - Visual analysis.

# %%
denoise_folder(
    gt_folder="validation/synthetic/sticks/clean_sticks",
    input_folder="validation/synthetic/sticks/noisy_sticks",
    output_folder="validation/synthetic/sticks/classic_denoised_sticks",
    methods=classic_methods,
    csv_path="validation/synthetic/sticks/classic_denoising_sticks_res.csv"
)
